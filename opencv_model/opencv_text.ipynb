# %%
from text_detect_open_cv import TextPositionTableDetector

detector = TextPositionTableDetector()

# %%
tables = detector._extract_text_regions("/Users/bingzhi/git/table_detection/page_0.jpg")

# %%
detector.debug_text_detection("/Users/bingzhi/git/table_detection/page_0.jpg")
# Out:
# === DEBUG: Text-based Table Detection ===
# Processing: /Users/bingzhi/git/table_detection/page_0.jpg
# Spatial filtering overlapping MSER regions from 203439 regions...
# Built spatial grid with 5879 occupied cells
# Spatial filtering complete: kept 14777 regions (removed 188662)
#
# Text Region Detection Results:
#   MSER method: 14777 regions
#   Morphological method: 0 regions
#   Contour method: 0 regions
# Fast deduplication of 14777 regions...
# Fast deduplication complete: 14451 unique regions
#   After deduplication: 14451 regions
# Debug image saved: debug_mser_regions.jpg
# Debug image saved: debug_morph_regions.jpg
# Debug image saved: debug_contour_regions.jpg
# Debug image saved: debug_all_text_regions.jpg
# Fast alignment analysis of 14451 regions...
# Fast alignment found 333 rows and 791 columns
#
# Alignment Analysis:
#   Potential table rows: 333
#   Potential table columns: 791
#     Row 1: 21 text regions at y≈262
#     Row 2: 6 text regions at y≈329
# ...

# %%
debug_info = detector.debug_text_detection("/Users/bingzhi/git/table_detection/page_0.png")
# Out:
# === DEBUG: Text-based Table Detection ===
# Processing: /Users/bingzhi/git/table_detection/page_0.png
# [ WARN:0@2.350] global loadsave.cpp:241 findDecoder imread_('/Users/bingzhi/git/table_detection/page_0.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 debug_info = detector.debug_text_detection("/Users/bingzhi/git/table_detection/page_0.png")
#
# File ~/git/table_detection/opencv_model/text_detect_open_cv.py:515, in TextPositionTableDetector.debug_text_detection(self, image_path, save_debug_images)
#     513 # Step 1: Extract text regions with method breakdown
#     514 img = cv2.imread(image_path)
# --> 515 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     517 # Get results from each method separately
#     518 mser_regions = self._extract_text_mser(gray)
#
# ...
